# %%
import re
file_path="C:\Users\User\Desktop\str.txt"
LL=[]
with open(file_path, 'r') as current:
    if len(current.read(1)) == 0:
        print('FILE IS EMPTY')
    else:
        current.seek(0)
        for line in current:
            LL.append(line)
            print(line)
# Out:
# SALES AUDIT REPORT-24OCT19     ZH6I-AEGBT
#
# STOCK              TICKET           CPN/STK          PTR    ACT
#
# NUMBER             NUMBER            TYPE            LNIATA IND
#
# PNR-VBTGVQ GRABOWSKI/MICHAL MR           AGT SINE-ABD TIME 1835
#
#       COMM AMT-         0.00       TKT AMT - EUR       108.29AX
#
#                    0809463253400       AT              ETR
#
#   7..U2-1000
#
#   8..U3-11074
#
# 9..U4-0                                                      ‡
#
# 10..U5-T2601
#
#  11..U6-108001EU08
#
#  12..U7-GUILDFORD IT MEETINGS
#
#  13..U8-18NOV19
#
#  14..U9-JEREMY SAADA
#
#
#
# PNR-IXBAWX LIUBETSKI/DZIANIS MR          AGT SINE-ABD TIME 1746
#
#       COMM AMT-         0.00       TKT AMT - EUR       267.83CA
#
#                    6289463253399       AT              ETR
#
#   2..U2-1000
#
#   3..U3-13128
#
#   7..U4-0
#
#   8..U5-T2601
#
#   9..U6-120006PG05
#
#  10..U7-MINSK MEETINGS
#
#  11..U8-20NOV19
#
#  12..U9-VERONIKA SMIRNOVA
#
#
#
# PNR-KMNWEZ CROW/JONATHAN MARK            AGT SINE-AAO TIME 1744
#
#       COMM AMT-         0.00       TKT AMT - EUR        50.00EX
#
#                    6289463253398       AT              ETR    A
#
# 91..Z*U5-102306AU04
#
#  92..Z*U8-A0505
#
#  93..Z*U2-1000
#
#  94..Z*U1-BLUE DATA WORKSHOPS
#
#
#
# PNR-BEWAVH RYABOV/ALEXANDER              AGT SINE-AAO TIME 1742
#
#       COMM AMT-         1.73       TKT AMT - EUR       242.55CA
#
#                    6289463253397       AT              ETR
#
# 89..Z*U8-A0502
#
#  90..Z*U2-1000
#
#  91..Z*U1-MEETINGS
#
#
#
# PNR-EYHHOT CAHILL/MICHAEL RYAN MR        AGT SINE-AAO TIME 1708
#
#       COMM AMT-         2.47       TKT AMT - EUR       320.03CA
#
#                    6289463253396       AT              ETR
#
# Product: WOT Blitz
#
# Activity Code: A1701
#
# Cost Center: 100104GL04
#
# Employee NO: 15542
#
# Purpose: Work with WoT Blits team on a couple projects they are Developing.
#
#
#
# PNR-DYJGNU MORRIS/LESLIE KEITH MR        AGT SINE-ABD TIME 1549‡
#
#       COMM AMT-         0.00       TKT AMT - EUR       319.44AX‡
#
#                                    FOP FEES              5.27AX
#
#                    2579463253395       AT              ETR    N
#
# PNR-DYJGNU GLUSHAKOVA/KRISTINA MS        AGT SINE-ABD TIME 1549
#
#       COMM AMT-         0.00       TKT AMT - EUR       319.44AX
#
#                                    FOP FEES              5.27AX
#
#                    2579463253394       AT              ETR    N
#
# 13..U3-19152  21724                                           ‡
#
# 14..U4-0
#
#  15..U5-A1202
#
#  16..U6-120001GL11
#
#  17..U7-AUDITS AND TRAINING
#
#  18..U8-22NOV19
#
#  19..U9-ROMAN ZANIN
#
#
#
# PNR-DYJGNU MORRIS/LESLIE KEITH MR        AGT SINE-ABD TIME 1547
#
#       COMM AMT-         0.00       TKT AMT - EUR       319.44AX
#
#                                    FOP FEES              5.27AX
#
#                    2579463253393       AT              ETR    V
#
# PNR-DYJGNU GLUSHAKOVA/KRISTINA MS        AGT SINE-ABD TIME 1547
#
#       COMM AMT-         0.00       TKT AMT - EUR       319.44AX
#
#                                    FOP FEES              5.27AX
#
#                    2579463253392       AT              ETR    V
#
#
#
# PNR-UMUFTU ROLLINS/JEFFREY ALAN MR       AGT SINE-ASB TIME 1534
#
#       COMM AMT-         7.10       TKT AMT - EUR      1004.99AX
#
#                    2579463253391       AT              ETR
#
# 7..U2-1244
#
#   8..U3-16721
#
#   9..U4-0
#
#  10..U6-100107GB06
#
# 11..U7-MANAGEMENT MEETINGS
#
#  12..U8-011119
#
#  13..U9-REQ BY JEFF ROLLINS
#
#
#
# PNR-UKJOPS MAKAROV/VIACHESLAV MR         AGT SINE-AAO TIME 1531‡
#
#       COMM AMT-         0.00       TKT AMT - EUR      1547.42AX‡
#
#                    5559463253390       AT              ETR
#
# A1201
#
# 1000
#
# Meetings
#
#
#
# PNR-CSDRJI STEPANOV/PAVEL MR             AGT SINE-AEP TIME 1436
#
#       COMM AMT-         1.24       TKT AMT - EUR       142.49CA
#
#                    6289463253389       AT              ETR
#
# Product – Blitz
#
# Employee ID 21537
#
# Purpose: business meeting with the colleagues in Minsk office, interview of the potential candidates
#
# Cost Center: 04MN80 Moscow WOT Blitz Dev
#
#
#
#
#
# PNR-HXOWDQ IVANEICHIK/TIMUR CHD CHD      AGT SINE-AEP TIME 1338
#
#       COMM AMT-         2.06       TKT AMT - EUR       276.79CA
#
#                    6289463253388       AT              ETR
#
# PNR-HXOWDQ IVANEICHIK/OLGA MS            AGT SINE-AEP TIME 1337
#
#       COMM AMT-         2.74       TKT AMT - EUR       347.03CA
#
#                    6289463253387       AT              ETR
#
# Family benefits
#
#
#
# PNR-HXLXWS IVANEICHIK/IVAN MR            AGT SINE-AEP TIME 1337
#
#       COMM AMT-         2.09       TKT AMT - EUR       282.03CA
#
#                    6289463253386       AT              ETR
#
#   2..U2-1000                                                   ‡
#
#   3..U3-15505
#
#   4..U4-0
#
#   5..U5-A0102
#
#   6..U6-100102GP58
#
#   7..U7-PLATFORM RELATIONS MEET UP COLLABORATION WITH MSQ PRODU
#
#     CTS
#
#   8..U8-110120
#
#   9..U9-IVAN IVANEICHIK
#
#
#
# PNR-LXYIXY LINDSAY/LAURA ANNE KER MRS    AGT SINE-AAO TIME 1116
#
#       COMM AMT-         1.06       TKT AMT - EUR       163.15AX
#
#                    3909463253385       AT              ETR
#
# PNR-LXYIXY LINDSAY/LAURA ANNE KER MRS    AGT SINE-AAO TIME 1116
#
#       COMM AMT-         0.24       TKT AMT - EUR       264.73AX‡
#
#                    1259463253384       AT              ETR     ‡
#
# Purpose: Enclave Exec team support and Team Sync / UK studio Opening
#
# Product: Enclave
#
# Cost Center: WG100104GL04
#
# Employee Number 16177
#
# Activity code: A1701
#
# Cost of Flight: 427.00
#
#
#
# PNR-MGWDDP PUTZKI/THOMAS MR              AGT SINE-ABD TIME 1039
#
#       COMM AMT-         0.00       TKT AMT - EUR       255.72AX
#
#                                    FOP FEES              4.61AX
#
#                    2209463253383       AT              ETR
#
#   7..U2-1000
#
#   8..U3-15232
#
#   9..U4-0
#
#  10..U5-A0404
#
#  11..U6-108002EU23
#
#  12..U7-GAMESCOM ADVISORY BOARD MEETING
#
# 13..U8-14NOV19                                                ‡
#
# 14..U9-JEAN MARC CODSI
#
#
#
# PNR-YCDTMA KOLMAKOVA/MARINA MS           AGT SINE-AAO TIME 1005
#
#       COMM AMT-         0.00       TKT AMT - EUR      1414.55AX
#
#                    5559463253382       AT              ETR
#
# Cost Center: 100101GL19
#
# Product: 1000
#
# Activity: A1008 HR Related: Education: Professional Development
#
# Employee: MARINA KOLMAKOVA / HRMS ID: 17993
#
#
#
# PNR-LAFTXW YIANGOU/YIANGOS MR            AGT SINE-AAO TIME 0952
#
#       COMM AMT-         1.75       TKT AMT - EUR      1829.49AX
#
#                    1259463253381       AT              ETR    V
#
# PNR-LAFTXW YIANGOU/YIANGOS MR            AGT SINE-AAO TIME 0925
#
#       COMM AMT-         1.75       TKT AMT - EUR      1829.49AX
#
#                    1259463253380       AT              ETR
#
# VK Personal
#
#
#
# AUDIT COUPONS-      18
#
# TOTALS     DAILY SALES              CASH/CHECK AMT
#
# EUR           9,155.97                    1,928.75
#
#               COMM AMT                  CREDIT AMT             ‡
#
#                 22.48                    7,227.22             ‡
#
# END OF REPORT

# %%
L=[]
string = open(file_path, 'r').read()
#string=" ".join(string.split())
string = string.replace('\n',' ')
#print string
#result = re.findall(r"ETR(.*)\bPNR", string)
#x=[x.group() for x in re.finditer(r'ETR(.*)PNR',string)]
#result=re.findall(r"ETR|PNR",string)
#result
#while len(string)>=3:
    #if re.search(r"ETR",string):

string=string.split("ETR") 
size=len(string)
Reason=[]
i=0
while i<size:
    string[i]=string[i].split("PNR")
    Reason.append(string[i][0])
    i+=1

del Reason[0]  
Reason[-1]=re.sub(r"AUDIT.+"," ",Reason[-1])

for i in range(len(Reason)):
    
    Reason[i]=re.sub(r"([ ]{2})","",Reason[i])
    x=re.findall(r"\d\.\.",Reason[i])
    if re.search(r"\d\.\.",Reason[i]):
        Reason[i]=re.sub(r"\d\.\."," ",Reason[i])
    elif re.search(r"\N\b", Reason[i]):
        print "YOOOOO"
    print Reason[i],i
# Out:
#   U2-1000  U3-11074  U4-0‡ 1 U5-T2601 1 U6-108001EU081 U7-GUILDFORD IT MEETINGS 1 U8-18NOV19 1 U9-JEREMY SAADA  0
#   U2-1000  U3-13128 U4-0 U5-T2601 U6-120006PG051 U7-MINSK MEETINGS1 U8-20NOV19 1 U9-VERONIKA SMIRNOVA  1
# A9 Z*U5-102306AU049 Z*U8-A0505 9 Z*U2-10009 Z*U1-BLUE DATA WORKSHOPS 2
#  8 Z*U8-A0502 9 Z*U2-10009 Z*U1-MEETINGS 3
#  Product: WOT Blitz Activity Code: A1701Cost Center: 100104GL04 Employee NO: 15542 Purpose: Work with WoT Blits team on a couple projects they are Developing.  4
# YOOOOO
# N 5
# N1 U3-1915221724 ‡ 1 U4-0 1 U5-A1202 1 U6-120001GL111 U7-AUDITS AND TRAINING 1 U8-22NOV19 1 U9-ROMAN ZANIN  6
# V 7
# V 8
#   U2-1244  U3-16721 U4-0 1 U6-100107GB06 1 U7-MANAGEMENT MEETINGS1 U8-0111191 U9-REQ BY JEFF ROLLINS  9
#  A1201 1000 Meetings  10
#  Product – Blitz Employee ID 21537 Purpose: business meeting with the colleagues in Minsk office, interview of the potential candidatesCost Center: 04MN80 Moscow WOT Blitz Dev  11
#   12
#  Family benefits  13
#   U2-1000 ‡  U3-15505 U4-0 U5-A0102 U6-100102GP58  U7-PLATFORM RELATIONS MEET UP COLLABORATION WITH MSQ PRODUCTS U8-110120  U9-IVAN IVANEICHIK 14
#   15
#  ‡ Purpose: Enclave Exec team support and Team Sync / UK studio OpeningProduct: EnclaveCost Center: WG100104GL04Employee Number 16177Activity code: A1701Cost of Flight: 427.00 16
#   U2-1000  U3-15232 U4-0 1 U5-A0404 1 U6-108002EU231 U7-GAMESCOM ADVISORY BOARD MEETING 1 U8-14NOV19‡ 1 U9-JEAN MARC CODSI 17
#  Cost Center: 100101GL19 Product: 1000 Activity: A1008 HR Related: Education: Professional Development Employee: MARINA KOLMAKOVA / HRMS ID: 17993 18
# V 19
#  VK Personal 20

# %%
#Dictionary style, key will be ticket number. Based on ticket number will return desired result. Just need to insert the ticket numbers you want.
PNR=[]
Request_Date=[]
Comm_AMT=[]
TKT_AMT=[]
Ticket=[]

for line in LL:
    test=line
    pattern1=re.compile(r"\s{2,}(\d+)(\s+)(\S+)")
    try:
        found1 = re.search(pattern1, test).group(1)  
        Ticket.append(found1)
    except AttributeError:
        found1 = '' 
del Ticket[7]
for line in LL:
    test=line
    pattern1=re.compile(r"(\S+) (\S+)(-)(\s+)(\d.\d+)(\s+)(\S+) (\S+) (-) (\S+)(\s+)(\d+.\d+)")
    
    try:
        found1 = re.search(pattern1, test).group(5)  
        Comm_AMT.append(found1)
        found2 = re.search(pattern1, test).group(12)
        TKT_AMT.append(found2)
        #Request_Date.append(found2)

    except AttributeError:
        found1 = '' 


for line in LL:
    test=line
    pattern1=re.compile(r"PNR-(.+?)\b")
    
    try:
        found1 = re.search(pattern1, test).group(1)  
        PNR.append(found1)
        #Request_Date.append(found2)

    except AttributeError:
        found1 = ''
        
print len(PNR)

for line in LL:
    test=line
    pattern2=re.compile(r"REPORT-(.+?)\b")
    try:
        found2 = re.search(pattern2, test).group(1)  
        Request_Date.append(found2)

    except AttributeError:
        found1 = '' 

Surname=[]
Name=[]
for line in LL:
    test=line
    pattern3=re.compile(r"PNR-(.+?) \b(.+?)\b(.+?)\b(.+?)\b")
    try:
        found3 = re.search(pattern3, test).group(2)  
        Surname.append(found3)
        found3 = re.search(pattern3, test).group(4)  
        Name.append(found3)

    except AttributeError:
        found3 = ''
# Out:
# 21

# %%
#print Request_Date
import itertools 
import pandas as pd
pd.set_option('display.max_columns', 100)  # or 1000
pd.set_option('display.max_rows', 100)  # or 1000
pd.set_option('display.max_colwidth', -1)  # or 199
L = list(itertools.repeat(Request_Date[0], len(PNR)))
print len(L),len(PNR),len(Ticket),len(TKT_AMT),len(Comm_AMT),len(Surname),len(Name),len(Reason)
DF=pd.DataFrame({"Request Data":L,"Airline Code":PNR,"Ticket Number":Ticket,"Ticket AMT":TKT_AMT,"Commision AMT":Comm_AMT,"Surname":Surname,"Name":Name,"Reason": Reason})
def print_full(x):
    pd.set_option('display.max_rows', len(x))
    print(x)
    pd.reset_option('display.max_rows')
print_full(DF)
pd.set_option('display.max_columns', 100)  # or 1000
pd.set_option('display.max_rows', 100)  # or 1000
pd.set_option('display.max_colwidth', -1)  # or 199
#{"Request Data":L,"Airline Code":PNR,"Ticket Number":Ticket,"Ticket AMT":TKT_AMT,"Commision AMT":Comm_AMT,"Surname":Surname,"Name":Name,
# Out:
# 21 21 21 21 21 21 21 21
#    Airline Code Commision AMT        Name  \
# 0   VBTGVQ       0.00          MICHAL
# 1   IXBAWX       0.00          DZIANIS
# 2   KMNWEZ       0.00          JONATHAN
# 3   BEWAVH       1.73          ALEXANDER
# 4   EYHHOT       2.47          MICHAEL
# 5   DYJGNU       0.00          LESLIE
# 6   DYJGNU       0.00          KRISTINA
# 7   DYJGNU       0.00          LESLIE
# 8   DYJGNU       0.00          KRISTINA
# 9   UMUFTU       7.10          JEFFREY
# 10  UKJOPS       0.00          VIACHESLAV
# 11  CSDRJI       1.24          PAVEL
# 12  HXOWDQ       2.06          TIMUR
# 13  HXOWDQ       2.74          OLGA
# 14  HXLXWS       2.09          IVAN
# 15  LXYIXY       1.06          LAURA
# 16  LXYIXY       0.24          LAURA
# 17  MGWDDP       0.00          THOMAS
# 18  YCDTMA       0.00          MARINA
# 19  LAFTXW       1.75          YIANGOS
# 20  LAFTXW       1.75          YIANGOS
#
#                                                                                                                                                                               Reason  \
# 0    7..U2-1000 8..U3-11074 9..U4-0‡ 10..U5-T2601 11..U6-108001EU0812..U7-GUILDFORD IT MEETINGS 13..U8-18NOV19 14..U9-JEREMY SAADA
# 1    2..U2-1000 3..U3-131287..U4-08..U5-T26019..U6-120006PG0510..U7-MINSK MEETINGS11..U8-20NOV19 12..U9-VERONIKA SMIRNOVA
# 2   A91..Z*U5-102306AU0492..Z*U8-A0505 93..Z*U2-100094..Z*U1-BLUE DATA WORKSHOPS
# 3    89..Z*U8-A0502 90..Z*U2-100091..Z*U1-MEETINGS
# 4    Product: WOT Blitz Activity Code: A1701Cost Center: 100104GL04 Employee NO: 15542 Purpose: Work with WoT Blits team on a couple projects they are Developing.
# 5   N
# 6   N13..U3-1915221724 ‡ 14..U4-0 15..U5-A1202 16..U6-120001GL1117..U7-AUDITS AND TRAINING 18..U8-22NOV19 19..U9-ROMAN ZANIN
# 7   V
# 8   V
# 9    7..U2-1244 8..U3-167219..U4-0 10..U6-100107GB06 11..U7-MANAGEMENT MEETINGS12..U8-01111913..U9-REQ BY JEFF ROLLINS
# 10   A1201 1000 Meetings
# 11   Product – Blitz Employee ID 21537 Purpose: business meeting with the colleagues in Minsk office, interview of the potential candidatesCost Center: 04MN80 Moscow WOT Blitz Dev
# 12
# 13   Family benefits
# 14   2..U2-1000 ‡ 3..U3-155054..U4-05..U5-A01026..U6-100102GP58 7..U7-PLATFORM RELATIONS MEET UP COLLABORATION WITH MSQ PRODUCTS8..U8-110120 9..U9-IVAN IVANEICHIK
# 15
# 16   ‡ Purpose: Enclave Exec team support and Team Sync / UK studio OpeningProduct: EnclaveCost Center: WG100104GL04Employee Number 16177Activity code: A1701Cost of Flight: 427.00
# 17   7..U2-1000 8..U3-152329..U4-0 10..U5-A0404 11..U6-108002EU2312..U7-GAMESCOM ADVISORY BOARD MEETING 13..U8-14NOV19‡ 14..U9-JEAN MARC CODSI
# 18   Cost Center: 100101GL19 Product: 1000 Activity: A1008 HR Related: Education: Professional Development Employee: MARINA KOLMAKOVA / HRMS ID: 17993
# 19  V
# 20   VK Personal
#
#    Request Data     Surname Ticket AMT  Ticket Number
# 0   24OCT19      GRABOWSKI   108.29     0809463253400
# 1   24OCT19      LIUBETSKI   267.83     6289463253399
# 2   24OCT19      CROW        50.00      6289463253398
# 3   24OCT19      RYABOV      242.55     6289463253397
# 4   24OCT19      CAHILL      320.03     6289463253396
# 5   24OCT19      MORRIS      319.44     2579463253395
# 6   24OCT19      GLUSHAKOVA  319.44     2579463253394
# 7   24OCT19      MORRIS      319.44     2579463253393
# 8   24OCT19      GLUSHAKOVA  319.44     2579463253392
# 9   24OCT19      ROLLINS     1004.99    2579463253391
# 10  24OCT19      MAKAROV     1547.42    5559463253390
# 11  24OCT19      STEPANOV    142.49     6289463253389
# 12  24OCT19      IVANEICHIK  276.79     6289463253388
# 13  24OCT19      IVANEICHIK  347.03     6289463253387
# 14  24OCT19      IVANEICHIK  282.03     6289463253386
# 15  24OCT19      LINDSAY     163.15     3909463253385
# 16  24OCT19      LINDSAY     264.73     1259463253384
# 17  24OCT19      PUTZKI      255.72     2209463253383
# 18  24OCT19      KOLMAKOVA   1414.55    5559463253382
# 19  24OCT19      YIANGOU     1829.49    1259463253381
# 20  24OCT19      YIANGOU     1829.49    1259463253380
